# %% [markdown]
# ---
# ## Comparative Study of Car License Plate Detection using YOLO and FastRCNN Models
# Recently there has been a rise on the use of technology to automatic many applications in various sectors. This project is one of them. It aims to evaluate and compare the performance of two object detection models, YOLO (You Only Look Once) and Fast R-CNN (Regions with CNN features), for a task on car license plate detection. Having a very accurate and efficient license plate detection is very important for many applications in any jurisdiction i.e, automated toll collection, parking management, tracking movement, vehicle counts, and law enforcement. This study seeks to identify which model offers the best balance between speed and accuracy across different datasets.
#
# Most state-of-the-art systems face an issue of balancing the trade-off between high accuracy and real-time processing speed. As different object detection models have distinct performance characteristics, it is indispensable to identify which model is optimal for a certain deployment scenario. This project explores and compares the performance of two well-known object detection models, namely YOLO and Fast R-CNN.
# YOLO is very fast and efficient, hence applicable for real-time applications. This network processes an entire image with one pass, predicting all bounding boxes and classes in one shot.
#
# Fast R-CNN has two stages where it proposes first and then classifies, hence offering higher accuracy. Due to this two-stage, it is somehow heavy in computation.
#
# In this project, by comparing YOLO and Fast R-CNN, it tries to find out which model offers the best balance between performance and efficiency for real-time car license plate detection on different datasets. It will take into consideration some key factors like accuracy of detection, speed of processing, and requirements of computational resources.
# Dataset
#
# The dataset originates from the research associated with the GitHub repository Real-time Auto License Plate Recognition with Jetson Nano. Its main purpose is for training machine learning models for automatic licence plate detection. It has information like images of vehicles and license plates, likely with bounding box annotations for supervised learning tasks. The dataset contains image data in png format, specifically images of vehicles and license plates used for recognition tasks. The images are annotated for the licence plate bounding information which will be used as supervision for our training.
#
# ## Project Development Approach
# The implementation will be following a defined approach in order to come up with final comparison results between YOLO and Fast R-CNN models hence accomplishing the car license plate detection. The major steps involved are data pre-processing, model training, performance evaluation, and speed assessment.
# - First, the original dataset from the Real-time Auto License Plate Recognition with Jetson Nano GitHub repository will be considered. These bounding box annotations should be translated into a format required by each model; this may include normalizing the coordinates and compatibility with the input format of YOLO and Fast R-CNN.
# - Then, the preprocessed dataset will be used to train YOLO and Fast R-CNN. Here, pre-trained weights will be used through transfer learning, which enables faster training and higher performance. The validation set will be used for hyperparameter tuning in order to optimize the model’s performance. On this a loss function will also be used for detection tasks on bounding box regression, to monitor the training process.
# - The performance of the trained models will be measured by standard object detection metrics.
#     - Intersection over Union - It refers to the measurement of overlapping between predicted and ground truth bounding boxes.
#     Mean Average Precision-mAP@XX - The accuracy of the models shall be measured using mAP. Therefore, the mAP@50-IoU threshold of 0.5-and mAP@75-IoU threshold of 0.75-will be calculated to give an overall view regarding how the model performs at different IoU thresholds.
#     - Precision and Recall - These two metrics will be used in analyzing the trade-off between false positives and false negatives.
#
# - The speeds of the models will be decided by measuring the time of inference on a dedicated hardware setup. Inference time will be calculated as the average time taken by a model to process one image. This apart, FPS will also be calculated to provide real-time performance metrics.
# - The results from performance and speed evaluation will be drawn together to conclude which model gives the best combination of accuracy and efficiency for real-time car license plate detection.
#
# ## Project AIM
# The main aim for the project is to conduct a computer vision based model training for detection of vehicle licences and then compare the performances and efficiency for real-time car license plate detection for YOLO and FastRCNN models.
#
#
# ## Project Objectives
# - To study and review relevant papers concerning object detection models with a bias toward license plate detection to understand the current trends and best practices in the field.
# - To clean and pre-process the car license plate dataset to make it ready for training.
# - To train both YOLO and Fast R-CNN models using the prepared dataset, optimizing each for accurate license plate detection.
# - To perform a comparative study of the YOLO and Fast R-CNN models in detecting license plates. Based on the accuracy, speed, and overall efficiency, access and compare models.
# - To evaluate the performance of the trained models using relevant performance metrics. and later compile a comprehensive final report summarizing the methodology, analysis, results, and conclusions of the project.

# %%
# install first coco related modules
# !pip install pycocotools -q
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# system setup
import os
import shutil
import glob
import time
import subprocess
import gc


# data hadnle
import json
import yaml
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# img and vis 
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image as PILImage
from matplotlib.patches import Rectangle
from IPython.display import display, HTML, Image

# torch and torchvision
import torch
import torchvision
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# COCO-related Modules
from pycocotools.coco import COCO
from coco_eval import CocoEvaluator
from coco_utils import get_coco_api_from_dataset

# train and eval Functions
from engine import train_one_epoch, evaluate

# 
# 
from tqdm import tqdm

# %%
os.listdir("/kaggle/input/yolo-plate-dataset")
# Out:
# ['yolo_plate_dataset']

# %%
len(os.listdir("/kaggle/input/yolo-plate-dataset/yolo_plate_dataset"))//2
# Out:
# 8260

# %%
import os
# List all files and folders in Google Drive
os.listdir("/kaggle/input/yolo-plate-dataset/yolo_plate_dataset")
# Out:
# ['CarLongPlateGen2621.txt',
#  'CarLongPlateGen3598.jpg',
#  'CarLongPlate708.txt',
#  'brightnessquandoi93.jpg',
#  'xemayBigPlate15.jpg',
#  'CarLongPlateGen2569.jpg',
#  'xemay1617.txt',
#  'ngoaigiao10.txt',
#  'CarLongPlateGen3435.txt',
#  'CarLongPlateGen121.jpg',
#  'CarLongPlateGen2374.jpg',
#  'CarLongPlateGen2897.jpg',
#  'CarLongPlateGen181.jpg',
#  'xemay1884.txt',
#  'CarLongPlateGen1514.jpg',
#  'brightnessquandoi35.jpg',
#  'CarLongPlate873.txt',
#  'CarLongPlateGen3640.jpg',
#  'CarLongPlate391.jpg',
#  'xemay427.jpg',
#  'CarLongPlateGen1893.txt',
#  'CarLongPlate694.jpg',
#  'xemay2024.jpg',
#  'CarLongPlateGen2969.jpg',
#  'CarLongPlateGen1758.jpg',
#  'xemay2179.jpg',
#  'CarLongPlateGen948.jpg',
#  'xemay428.jpg',
#  'CarLongPlateGen2175.txt',
#  'CarLongPlateGen3868.jpg',
#  'CarLongPlateGen558.txt',
#  'CarLongPlateGen3875.jpg',
#  'CarLongPlateGen2292.txt',
#  'CarLongPlateGen920.txt',
#  'cropquandoi35.jpg',
#  'CarLongPlateGen3181.jpg',
#  'CarLongPlate975.jpg',
#  'quandoi11.jpg',
#  'CarLongPlateGen3884.jpg',
#  'CarLongPlateGen1386.txt',
#  'CarLongPlateGen2168.txt',
#  'xemay323.jpg',
#  'CarLongPlateGen655.txt',
#  'CarLongPlateGen3628.jpg',
#  'CarLongPlateGen3334.jpg',
#  'CarLongPlateGen3474.jpg',
#  'xemay1466.txt',
#  'CarLongPlateGen2802.txt',
#  'CarLongPlateGen1614.jpg',
#  'CarLongPlateGen3609.jpg',
#  'CarLongPlateGen2549.jpg',
#  'quandoi76.jpg',
#  'CarLongPlate406.jpg',
#  'CarLongPlateGen1470.jpg',
#  'cropquandoi5.txt',
#  'xemay1922.txt',
#  'CarLongPlateGen114.jpg',
#  'xemay1625.jpg',
#  'xemay2239.jpg',
#  'CarLongPlateGen3876.jpg',
#  'CarLongPlateGen569.jpg',
#  'CarLongPlateGen2654.txt',
#  'CarLongPlateGen948.txt',
#  'xemay2302.jpg',
#  'quandoi110.txt',
#  'CarLongPlateGen1274.jpg',
#  'CarLongPlateGen3823.txt',
#  'CarLongPlateGen1361.jpg',
#  'CarLongPlateGen2584.txt',
#  'CarLongPlateGen2203.jpg',
#  'CarLongPlateGen178.txt',
#  'xemay827.jpg',
#  'CarLongPlateGen2598.txt',
#  'CarLongPlateGen3441.jpg',
#  'CarLongPlateGen2003.txt',
#  'CarLongPlateGen3737.jpg',
#  'CarLongPlateGen3374.txt',
#  'CarLongPlateGen2442.txt',
#  'xemay2196.txt',
#  'CarLongPlateGen1469.txt',
#  'rotatequandoi81.jpg',
#  'CarLongPlateGen2718.txt',
#  'CarLongPlateGen1018.jpg',
#  'xemay172.jpg',
#  'CarLongPlateGen893.txt',
#  'boderquandoi79.txt',
#  'CarLongPlateGen2205.jpg',
#  'xemay31.jpg',
#  'xemay1882.txt',
#  'CarLongPlateGen3869.txt',
#  'CarLongPlate577.jpg',
#  'CarLongPlateGen3340.txt',
#  'ngoaigiao6.jpg',
#  'xemay815.jpg',
#  'CarLongPlateGen1355.jpg',
#  'CarLongPlateGen3334.txt',
#  'cropquandoi95.txt',
#  'CarLongPlateGen1543.jpg',
#  'boderquandoi60.txt',
#  'CarLongPlateGen2690.jpg',
#  'CarLongPlateGen2831.txt',
#  'CarLongPlateGen2463.txt',
#  'ngoaigiao2.txt',
#  'xemay1644.jpg',
#  'CarLongPlateGen1212.jpg',
#  'CarLongPlate594.txt',
#  'CarLongPlateGen560.jpg',
#  'xemay1549.txt',
#  'ngoaigiao0.txt',
#  'xemay949.txt',
#  'CarLongPlateGen3321.jpg',
#  'CarLongPlateGen289.txt',
#  'CarLongPlate958.jpg',
#  'CarLongPlateGen2674.txt',
#  'CarLongPlateGen2929.jpg',
#  'CarLongPlateGen2709.jpg',
#  'CarLongPlateGen517.txt',
#  'xemay78.txt',
#  'xemay11.txt',
#  'CarLongPlate829.txt',
#  'xemay1052.jpg',
#  'CarLongPlateGen697.txt',
#  'CarLongPlateGen1516.txt',
#  'CarLongPlateGen2162.txt',
#  'xemay2134.jpg',
#  'CarLongPlateGen1375.jpg',
#  'CarLongPlate107.jpg',
#  'xemay295.txt',
#  'xemay1327.jpg',
#  'xemay431.jpg',
#  'xemay1790.txt',
#  'CarLongPlateGen1932.txt',
#  'CarLongPlateGen354.txt',
#  'CarLongPlateGen1462.txt',
#  'CarLongPlate396.jpg',
#  'xemay5.jpg',
#  'xemay177.jpg',
#  'CarLongPlate990.txt',
#  'xemay1904.jpg',
#  'xemay1191.jpg',
#  'CarLongPlateGen1805.txt',
#  'CarLongPlateGen1408.txt',
#  'CarLongPlateGen3522.jpg',
#  'boderquandoi38.jpg',
#  'CarLongPlateGen3319.jpg',
#  'xemayBigPlate39.txt',
#  'cropngoaigiao8.jpg',
#  'xemay1212.jpg',
#  'CarLongPlateGen1595.txt',
#  'CarLongPlateGen1542.jpg',
#  'CarLongPlate845.jpg',
#  'CarLongPlateGen319.jpg',
#  'CarLongPlateGen1413.txt',
#  'CarLongPlateGen116.txt',
#  'CarLongPlate22.txt',
#  'CarLongPlate780.txt',
#  'xemay575.jpg',
#  'xemay1527.txt',
#  'CarLongPlateGen341.txt',
#  'CarLongPlateGen3198.txt',
#  'CarLongPlateGen1377.jpg',
#  'xemayBigPlate209.jpg',
#  'cropquandoi18.txt',
#  'CarLongPlateGen2746.jpg',
#  'CarLongPlateGen1786.txt',
#  'CarLongPlateGen2672.jpg',
#  'quandoi3.jpg',
#  'CarLongPlate865.jpg',
#  'CarLongPlate183.txt',
#  'CarLongPlateGen3830.txt',
#  'CarLongPlateGen3796.txt',
#  'xemay2148.txt',
#  'CarLongPlateGen280.jpg',
#  'CarLongPlateGen2229.jpg',
#  'CarLongPlateGen1095.jpg',
#  'CarLongPlateGen2256.jpg',
#  'xemay107.txt',
#  'CarLongPlateGen223.jpg',
#  'CarLongPlateGen408.jpg',
#  'CarLongPlateGen357.jpg',
#  'CarLongPlate365.jpg',
#  'CarLongPlateGen2274.jpg',
#  'xemay539.txt',
#  'CarLongPlateGen363.jpg',
#  'CarLongPlateGen2698.jpg',
#  'CarLongPlateGen2169.jpg',
#  'CarLongPlateGen3866.txt',
#  'xemay1131.txt',
#  'CarLongPlateGen2056.jpg',
#  'CarLongPlate68.txt',
#  'xemay724.jpg',
#  'xemay1104.txt',
#  'CarLongPlateGen614.txt',
#  'xemay1385.jpg',
#  'xemay1109.txt',
#  'CarLongPlate942.jpg',
#  'xemay576.jpg',
#  'xemay959.txt',
#  'CarLongPlate5.jpg',
#  'boderngoaigiao7.jpg',
#  'CarLongPlateGen3279.txt',
#  'CarLongPlate345.jpg',
#  'xemay1176.jpg',
#  'boderquandoi90.txt',
#  'xemay2359.txt',
#  'CarLongPlateGen1803.txt',
#  'xemay1423.txt',
#  'quandoi50.txt',
#  'CarLongPlateGen104.jpg',
#  'xemay1430.txt',
#  'ngoaigiao4.jpg',
#  'ngoaigiao6.txt',
#  'CarLongPlate830.txt',
#  'xemay1547.txt',
#  'CarLongPlateGen1267.jpg',
#  'CarLongPlateGen3070.jpg',
#  'CarLongPlateGen537.txt',
#  'CarLongPlateGen1939.txt',
#  'CarLongPlateGen927.txt',
#  'xemay325.txt',
#  'CarLongPlateGen972.jpg',
#  'xemay1216.jpg',
#  'xemay2459.txt',
#  'CarLongPlateGen2343.txt',
#  'xemayBigPlate40.txt',
#  'CarLongPlateGen1794.txt',
#  'CarLongPlateGen378.jpg',
#  'xemay501.txt',
#  'CarLongPlate111.txt',
#  'cropquandoi83.txt',
#  'xemay603.txt',
#  'CarLongPlate334.txt',
#  'CarLongPlate539.jpg',
#  'CarLongPlateGen3345.jpg',
#  'xemay1355.jpg',
#  'cropquandoi96.txt',
#  'xemay2299.jpg',
#  'CarLongPlate233.jpg',
#  'CarLongPlateGen632.txt',
#  'ngoaigiao12.txt',
#  'CarLongPlateGen2305.txt',
#  'xemay739.txt',
#  'CarLongPlateGen992.txt',
#  'CarLongPlateGen1956.txt',
#  'CarLongPlateGen177.jpg',
#  'xemay1502.jpg',
#  'xemay582.jpg',
#  'cropquandoi1.jpg',
#  'CarLongPlateGen1272.txt',
#  'xemay1580.txt',
#  'CarLongPlateGen1230.txt',
#  'CarLongPlateGen2383.txt',
#  'CarLongPlateGen1412.txt',
#  'CarLongPlateGen1009.jpg',
#  'xemay73.txt',
#  'CarLongPlate29.jpg',
#  'CarLongPlateGen3201.txt',
#  'CarLongPlateGen3437.txt',
#  'xemay2430.jpg',
#  'CarLongPlateGen2715.jpg',
#  'CarLongPlateGen2906.txt',
#  'CarLongPlateGen3001.txt',
#  'CarLongPlateGen2556.txt',
#  'CarLongPlateGen1357.jpg',
#  'xemay539.jpg',
#  'boderngoaigiao15.txt',
#  'xemay1782.jpg',
#  'CarLongPlateGen2108.jpg',
#  'xemay342.jpg',
#  'xemay464.txt',
#  'rotatequandoi51.txt',
#  'CarLongPlateGen1778.txt',
#  'CarLongPlateGen3275.txt',
#  'CarLongPlateGen840.txt',
#  'xemay1204.txt',
#  'rotatequandoi84.jpg',
#  'CarLongPlateGen172.txt',
#  'xemayBigPlate92.txt',
#  'CarLongPlate471.txt',
#  'CarLongPlateGen3497.txt',
#  'CarLongPlateGen1300.jpg',
#  'CarLongPlate50.txt',
#  'CarLongPlateGen4.txt',
#  'xemay1609.jpg',
#  'xemay651.txt',
#  'CarLongPlateGen1840.jpg',
#  'CarLongPlateGen2188.jpg',
#  'CarLongPlateGen2594.txt',
#  'cropquandoi105.txt',
#  'CarLongPlateGen2474.txt',
#  'xemay1954.jpg',
#  'xemay401.txt',
#  'CarLongPlate578.jpg',
#  'CarLongPlateGen1218.txt',
#  'CarLongPlate779.txt',
#  'xemay2473.txt',
#  'xemay1741.txt',
#  'CarLongPlateGen3741.jpg',
#  'CarLongPlateGen2222.jpg',
#  'cropquandoi100.txt',
#  'xemay1111.txt',
#  'xemay1664.txt',
#  'xemay365.jpg',
#  'xemay1851.txt',
#  'xemay1837.jpg',
#  'CarLongPlateGen2287.txt',
#  'CarLongPlateGen3489.txt',
#  'xemay2003.jpg',
#  'rotatequandoi99.txt',
#  'CarLongPlate680.jpg',
#  'CarLongPlate273.jpg',
#  'CarLongPlate381.jpg',
#  'CarLongPlateGen3012.txt',
#  'brightnessquandoi61.txt',
#  'CarLongPlateGen786.jpg',
#  'CarLongPlateGen1346.txt',
#  'CarLongPlateGen1426.jpg',
#  'CarLongPlateGen1211.jpg',
#  'xemay362.txt',
#  'xemay1313.jpg',
#  'CarLongPlate393.txt',
#  'CarLongPlate238.txt',
#  'CarLongPlate82.jpg',
#  'CarLongPlate99.jpg',
#  'CarLongPlateGen2691.txt',
#  'CarLongPlateGen2428.jpg',
#  'CarLongPlateGen1412.jpg',
#  'CarLongPlateGen298.jpg',
#  'CarLongPlateGen1566.jpg',
#  'xemay1519.txt',
#  'CarLongPlateGen3112.txt',
#  'CarLongPlateGen3370.txt',
#  'CarLongPlateGen1712.txt',
#  'CarLongPlateGen2411.txt',
#  'CarLongPlateGen748.txt',
#  'CarLongPlateGen1835.txt',
#  'CarLongPlateGen1904.jpg',
#  'CarLongPlate824.jpg',
#  'CarLongPlate180.txt',
#  'xemay260.jpg',
#  'cropquandoi42.jpg',
#  'rotatequandoi5.jpg',
#  'xemay1265.txt',
#  'quandoi66.jpg',
#  'CarLongPlateGen3606.jpg',
#  'CarLongPlateGen372.jpg',
#  'CarLongPlate508.txt',
#  'xemay1215.jpg',
#  'xemay932.txt',
#  'CarLongPlateGen2782.jpg',
#  'xemay2248.txt',
#  'CarLongPlateGen583.jpg',
#  'CarLongPlateGen2690.txt',
#  'CarLongPlate71.txt',
#  'xemay2468.txt',
#  'CarLongPlateGen384.jpg',
#  'CarLongPlateGen3577.jpg',
#  'xemay1377.jpg',
#  'xemay1238.jpg',
#  'CarLongPlateGen3795.jpg',
#  'xemay853.jpg',
#  'CarLongPlateGen1298.txt',
#  'CarLongPlate17.txt',
#  'xemay793.txt',
#  'xemay655.jpg',
#  'CarLongPlate878.txt',
#  'CarLongPlateGen3372.jpg',
#  'CarLongPlateGen1235.jpg',
#  'xemay2337.jpg',
#  'xemay641.txt',
#  'CarLongPlateGen323.jpg',
#  'CarLongPlateGen1416.jpg',
#  'xemay2464.jpg',
#  'CarLongPlateGen245.txt',
#  'CarLongPlateGen1381.jpg',
#  'CarLongPlateGen3522.txt',
#  'CarLongPlateGen1255.jpg',
#  'CarLongPlateGen1816.txt',
#  'xemayBigPlate215.txt',
#  'CarLongPlateGen3355.txt',
#  'CarLongPlateGen2858.txt',
#  'xemay2017.txt',
#  'CarLongPlateGen1388.txt',
#  'CarLongPlateGen3664.txt',
#  'CarLongPlateGen733.jpg',
#  'xemay2132.txt',
#  'CarLongPlateGen595.txt',
#  'CarLongPlateGen1729.jpg',
#  'CarLongPlateGen3409.jpg',
#  'xemay1732.txt',
#  'xemayBigPlate108.jpg',
#  'CarLongPlate142.jpg',
#  'CarLongPlateGen3288.txt',
#  'CarLongPlateGen1438.jpg',
#  'xemayBigPlate213.txt',
#  'CarLongPlateGen1999.jpg',
#  'xemay1154.txt',
#  'xemay445.jpg',
#  'xemay464.jpg',
#  'CarLongPlateGen2350.txt',
#  'xemay2425.jpg',
#  'CarLongPlateGen668.jpg',
#  'xemay1003.txt',
#  'CarLongPlateGen1471.txt',
#  'CarLongPlateGen2629.jpg',
#  'xemay626.txt',
#  'xemay1220.txt',
#  'xemay462.jpg',
#  'quandoi79.jpg',
#  'CarLongPlateGen3649.jpg',
#  'xemay8.jpg',
#  'cropquandoi81.jpg',
#  'xemay749.jpg',
#  'xemay1724.txt',
#  'brightnessquandoi23.jpg',
#  'xemay637.jpg',
#  'CarLongPlateGen2393.jpg',
#  'CarLongPlateGen3114.jpg',
#  'CarLongPlateGen1127.jpg',
#  'CarLongPlateGen1796.jpg',
#  'xemay1880.txt',
#  'xemay1267.jpg',
#  'brightnessquandoi20.jpg',
#  'CarLongPlateGen853.jpg',
#  'CarLongPlateGen2312.jpg',
#  'CarLongPlate949.jpg',
#  'CarLongPlate826.jpg',
#  'CarLongPlateGen317.jpg',
#  'xemay16.txt',
#  'xemay2173.txt',
#  'CarLongPlateGen2830.jpg',
#  'CarLongPlateGen1771.jpg',
#  'CarLongPlateGen2065.txt',
#  'CarLongPlate162.txt',
#  'CarLongPlateGen2573.txt',
#  'CarLongPlate321.txt',
#  'CarLongPlate231.txt',
#  'xemay2174.txt',
#  'xemay791.txt',
#  'CarLongPlateGen785.txt',
#  'CarLongPlateGen478.jpg',
#  'xemay1555.txt',
#  'CarLongPlateGen1403.txt',
#  'CarLongPlateGen87.jpg',
#  'xemay871.jpg',
#  'CarLongPlateGen1774.jpg',
#  'xemay1727.txt',
#  'CarLongPlateGen1961.txt',
#  'CarLongPlateGen1468.txt',
#  'CarLongPlateGen2339.txt',
#  'CarLongPlate460.txt',
#  'rotatequandoi91.jpg',
#  'xemay171.jpg',
#  'quandoi2.txt',
#  'CarLongPlateGen3853.jpg',
#  'xemay1140.jpg',
#  'xemay656.jpg',
#  'CarLongPlateGen2671.jpg',
#  'xemayBigPlate223.jpg',
#  'xemay889.jpg',
#  'CarLongPlateGen527.jpg',
#  'xemay2101.jpg',
#  'CarLongPlateGen2627.jpg',
#  'CarLongPlateGen1064.txt',
#  'CarLongPlateGen3836.txt',
#  'quandoi79.txt',
#  'CarLongPlateGen179.txt',
#  'CarLongPlateGen3128.txt',
#  'CarLongPlateGen2269.jpg',
#  'CarLongPlateGen1152.txt',
#  'xemay1074.txt',
#  'CarLongPlateGen43.txt',
#  'CarLongPlateGen275.jpg',
#  'xemay1429.jpg',
#  'xemayBigPlate181.jpg',
#  'CarLongPlateGen420.txt',
#  'CarLongPlateGen3863.txt',
#  'xemay578.jpg',
#  'xemay1823.jpg',
#  'cropquandoi4.jpg',
#  'xemay1635.txt',
#  'CarLongPlate375.jpg',
#  'xemay1148.txt',
#  'xemay1077.txt',
#  'CarLongPlateGen1574.txt',
#  'xemayBigPlate63.txt',
#  'CarLongPlateGen3228.jpg',
#  'CarLongPlate529.txt',
#  'xemay470.jpg',
#  'CarLongPlateGen2021.txt',
#  'xemay2214.jpg',
#  'rotatequandoi2.txt',
#  'xemay747.txt',
#  'ngoaigiao1.jpg',
#  'CarLongPlate309.txt',
#  'CarLongPlateGen3783.txt',
#  'CarLongPlate84.txt',
#  'CarLongPlate648.txt',
#  'CarLongPlateGen624.jpg',
#  'CarLongPlateGen2083.txt',
#  'CarLongPlateGen3511.txt',
#  'xemay1204.jpg',
#  'CarLongPlateGen3215.txt',
#  'xemay1463.jpg',
#  'brightnessngoaigiao12.jpg',
#  'CarLongPlateGen2040.jpg',
#  'CarLongPlateGen1319.txt',
#  'CarLongPlateGen52.txt',
#  'xemay1089.jpg',
#  'CarLongPlateGen660.jpg',
#  'CarLongPlateGen2629.txt',
#  'CarLongPlate558.txt',
#  'CarLongPlateGen2560.jpg',
#  'CarLongPlateGen2852.jpg',
#  'CarLongPlate743.txt',
#  'xemay153.jpg',
#  'CarLongPlateGen949.txt',
#  'CarLongPlateGen1051.txt',
#  'xemay1910.txt',
#  'CarLongPlateGen2012.txt',
#  'CarLongPlateGen820.txt',
#  'CarLongPlateGen1418.txt',
#  'CarLongPlate129.jpg',
#  'CarLongPlateGen1853.jpg',
#  'cropquandoi25.jpg',
#  'CarLongPlateGen1663.txt',
#  'xemay1770.jpg',
#  'xemay606.txt',
#  'CarLongPlateGen967.jpg',
#  'CarLongPlateGen2943.jpg',
#  'CarLongPlateGen3225.jpg',
#  'CarLongPlateGen1173.txt',
#  'xemay2109.txt',
#  'CarLongPlateGen2617.txt',
#  'CarLongPlateGen297.jpg',
#  'CarLongPlate132.txt',
#  'CarLongPlateGen1186.txt',
#  'xemay13.txt',
#  'xemay2358.jpg',
#  'CarLongPlateGen1785.txt',
#  'CarLongPlateGen1404.txt',
#  'CarLongPlateGen2929.txt',
#  'xemay1719.jpg',
#  'CarLongPlateGen415.txt',
#  'xemay856.txt',
#  'CarLongPlateGen626.txt',
#  'boderquandoi45.jpg',
#  'xemay1434.jpg',
#  'xemay974.jpg',
#  'CarLongPlateGen2171.jpg',
#  'CarLongPlate721.jpg',
#  'CarLongPlateGen3280.jpg',
#  'CarLongPlateGen2270.jpg',
#  'xemay400.jpg',
#  'CarLongPlate798.jpg',
#  'CarLongPlateGen246.jpg',
#  'CarLongPlate64.jpg',
#  'CarLongPlate370.jpg',
#  'CarLongPlateGen2535.jpg',
#  'CarLongPlate713.jpg',
#  'CarLongPlate627.jpg',
#  'CarLongPlateGen2193.txt',
#  'xemay1526.txt',
#  'xemay2285.jpg',
#  'CarLongPlateGen1377.txt',
#  'CarLongPlateGen1128.jpg',
#  'xemay1129.txt',
#  'xemay1961.jpg',
#  'CarLongPlateGen3677.txt',
#  'xemay192.jpg',
#  'CarLongPlateGen1447.txt',
#  'CarLongPlate212.jpg',
#  'boderquandoi25.txt',
#  'xemay1999.txt',
#  'xemay1682.txt',
#  'boderquandoi26.jpg',
#  'xemay100.txt',
#  'CarLongPlateGen3683.jpg',
#  'CarLongPlateGen171.txt',
#  'CarLongPlateGen2179.txt',
#  'CarLongPlateGen2916.jpg',
#  'CarLongPlate831.txt',
#  'xemay929.jpg',
#  'CarLongPlate995.jpg',
#  'CarLongPlate337.jpg',
#  'xemay1812.txt',
#  'xemay1795.txt',
#  'CarLongPlateGen1804.jpg',
#  'CarLongPlateGen3062.jpg',
#  'CarLongPlate71.jpg',
#  'CarLongPlate684.txt',
#  'CarLongPlateGen1968.txt',
#  'CarLongPlateGen2440.txt',
#  'xemay1318.txt',
#  'CarLongPlateGen3286.txt',
#  'xemayBigPlate4.txt',
#  'xemay1070.txt',
#  'xemay380.txt',
#  'CarLongPlateGen3047.txt',
#  'CarLongPlateGen606.jpg',
#  'xemay881.jpg',
#  'CarLongPlateGen1291.txt',
#  'xemay682.jpg',
#  'xemay1484.txt',
#  'brightnessquandoi25.txt',
#  'CarLongPlateGen2070.txt',
#  'ngoaigiao14.txt',
#  'xemay810.jpg',
#  'CarLongPlateGen479.txt',
#  'CarLongPlateGen358.jpg',
#  'xemay2154.txt',
#  'CarLongPlate984.jpg',
#  'cropquandoi34.txt',
#  'CarLongPlateGen1347.jpg',
#  'CarLongPlateGen3171.txt',
#  'CarLongPlateGen2678.txt',
#  'xemay1958.jpg',
#  'CarLongPlateGen3396.txt',
#  'boderquandoi36.txt',
#  'CarLongPlateGen1409.jpg',
#  'CarLongPlateGen3135.txt',
#  'CarLongPlateGen18.jpg',
#  'CarLongPlateGen1080.jpg',
#  'CarLongPlateGen1182.jpg',
#  'CarLongPlateGen1891.txt',
#  'CarLongPlateGen336.txt',
#  'cropquandoi63.jpg',
#  'CarLongPlateGen222.txt',
#  'xemay2201.txt',
#  'xemay1483.txt',
#  'CarLongPlate220.txt',
#  'xemayBigPlate125.txt',
#  'CarLongPlateGen1458.jpg',
#  'xemay134.jpg',
#  'xemayBigPlate195.jpg',
#  'xemay1870.jpg',
#  'xemay1961.txt',
#  'boderquandoi87.jpg',
#  'rotatequandoi32.jpg',
#  'xemay123.txt',
#  'xemay175.txt',
#  'CarLongPlateGen953.txt',
#  'xemay2440.txt',
#  'CarLongPlate484.jpg',
#  'brightnessquandoi85.txt',
#  'xemay2401.jpg',
#  'CarLongPlate455.jpg',
#  'CarLongPlateGen1389.jpg',
#  'xemay2186.txt',
#  'CarLongPlateGen3269.jpg',
#  'CarLongPlateGen2344.txt',
#  'CarLongPlateGen2885.txt',
#  'xemayBigPlate210.txt',
#  'xemay917.jpg',
#  'xemay716.jpg',
#  'CarLongPlateGen3459.txt',
#  'CarLongPlateGen3648.txt',
#  'xemay1705.txt',
#  'CarLongPlateGen2397.jpg',
#  'CarLongPlate678.jpg',
#  'CarLongPlateGen3127.jpg',
#  'CarLongPlate912.txt',
#  'CarLongPlateGen2694.txt',
#  'xemay752.txt',
#  'xemay476.txt',
#  'CarLongPlateGen168.jpg',
#  'CarLongPlateGen151.txt',
#  'xemay1270.txt',
#  'CarLongPlateGen1705.jpg',
#  'xemay24.jpg',
#  'CarLongPlateGen153.jpg',
#  'xemay466.txt',
#  'CarLongPlateGen2029.txt',
#  'CarLongPlateGen9.jpg',
#  'CarLongPlateGen1175.jpg',
#  'CarLongPlate269.txt',
#  'CarLongPlateGen2251.txt',
#  'xemay1085.txt',
#  'CarLongPlateGen1035.txt',
#  'CarLongPlateGen429.jpg',
#  'CarLongPlateGen1901.jpg',
#  'CarLongPlateGen3506.txt',
#  'CarLongPlateGen316.jpg',
#  'CarLongPlateGen1843.txt',
#  'xemay2176.jpg',
#  'CarLongPlateGen3234.jpg',
#  'CarLongPlateGen3211.jpg',
#  'CarLongPlate789.txt',
#  'xemay1873.txt',
#  'CarLongPlateGen1330.jpg',
#  'CarLongPlate929.jpg',
#  'CarLongPlate510.txt',
#  'xemay1020.txt',
#  'xemay888.txt',
#  'xemay691.txt',
#  'CarLongPlateGen1487.txt',
#  'boderquandoi26.txt',
#  'CarLongPlateGen1232.txt',
#  'CarLongPlateGen917.txt',
#  'xemay664.jpg',
#  'brightnessquandoi21.txt',
#  'xemay1576.jpg',
#  'CarLongPlateGen1394.txt',
#  'CarLongPlate572.txt',
#  'CarLongPlateGen3306.jpg',
#  'xemay1062.txt',
#  'xemay1986.jpg',
#  'CarLongPlate206.txt',
#  'CarLongPlateGen899.jpg',
#  'CarLongPlateGen1945.jpg',
#  'xemay1653.txt',
#  'CarLongPlateGen1714.jpg',
#  'cropquandoi94.jpg',
#  'xemay1262.jpg',
#  'CarLongPlateGen2318.txt',
#  'CarLongPlate489.txt',
#  'xemayBigPlate114.txt',
#  'CarLongPlateGen2997.jpg',
#  'CarLongPlate661.jpg',
#  'xemay258.jpg',
#  'CarLongPlateGen3464.txt',
#  'cropquandoi23.jpg',
#  'CarLongPlateGen2507.jpg',
#  'xemay987.jpg',
#  'CarLongPlateGen1023.txt',
#  'brightnessngoaigiao12.txt',
#  'CarLongPlateGen2157.txt',
#  'CarLongPlate778.txt',
#  'cropngoaigiao3.jpg',
#  'CarLongPlate819.jpg',
#  'CarLongPlateGen2109.txt',
#  'rotatequandoi80.jpg',
#  'xemayBigPlate41.txt',
#  'CarLongPlateGen278.jpg',
#  'CarLongPlateGen1543.txt',
#  'xemay1259.jpg',
#  'CarLongPlateGen96.jpg',
#  'xemay1290.jpg',
#  'CarLongPlate47.txt',
#  'xemay1979.txt',
#  'CarLongPlateGen2332.jpg',
#  'CarLongPlate90.txt',
#  'CarLongPlateGen699.jpg',
#  'CarLongPlateGen531.txt',
#  'CarLongPlateGen1561.jpg',
#  'xemay2101.txt',
#  'CarLongPlateGen2174.jpg',
#  'CarLongPlateGen1352.txt',
#  'CarLongPlateGen1027.txt',
#  'CarLongPlateGen2925.txt',
#  'CarLongPlateGen1844.txt',
#  'xemay243.txt',
#  'CarLongPlate797.txt',
#  'xemay133.txt',
#  'brightnessquandoi71.txt',
#  'CarLongPlateGen3136.jpg',
#  'CarLongPlateGen2553.txt',
#  'CarLongPlateGen898.txt',
#  'xemay2321.jpg',
#  'xemay2096.jpg',
#  'xemay132.txt',
#  'CarLongPlate861.txt',
#  'CarLongPlateGen3579.txt',
#  'xemay49.txt',
#  'CarLongPlateGen680.txt',
#  'CarLongPlateGen3101.txt',
#  'xemay26.jpg',
#  'quandoi55.txt',
#  'xemay500.jpg',
#  'CarLongPlateGen3043.jpg',
#  'CarLongPlateGen2400.txt',
#  'xemay188.txt',
#  'quandoi64.txt',
#  'xemay308.jpg',
#  'CarLongPlateGen2714.jpg',
#  'CarLongPlateGen2190.jpg',
#  'CarLongPlateGen2893.jpg',
#  'CarLongPlateGen1617.txt',
#  'xemay371.jpg',
#  'CarLongPlateGen2609.txt',
#  'xemay1045.jpg',
#  'boderquandoi58.txt',
#  'CarLongPlateGen3888.txt',
#  'brightnessquandoi50.jpg',
#  'xemay1602.jpg',
#  'CarLongPlateGen649.jpg',
#  'CarLongPlateGen1407.txt',
#  'CarLongPlateGen515.txt',
#  'rotatequandoi93.txt',
#  'CarLongPlateGen3835.jpg',
#  'CarLongPlate36.jpg',
#  'CarLongPlateGen1688.txt',
#  'CarLongPlate189.jpg',
#  'xemay1506.txt',
#  'CarLongPlateGen1690.txt',
#  'xemay2392.jpg',
#  'CarLongPlate386.txt',
#  'xemay1060.jpg',
#  'xemay2277.jpg',
#  'CarLongPlate344.jpg',
#  'CarLongPlateGen1876.txt',
#  'CarLongPlateGen3616.txt',
#  'CarLongPlateGen400.jpg',
#  'CarLongPlateGen521.jpg',
#  'CarLongPlateGen1783.jpg',
#  'CarLongPlate19.txt',
#  'xemay1712.jpg',
#  'CarLongPlateGen2297.jpg',
#  'CarLongPlateGen997.txt',
#  'CarLongPlate763.txt',
#  'xemay1983.jpg',
#  'xemay2404.txt',
#  'xemay1863.txt',
#  'xemay2204.jpg',
#  'xemay2207.txt',
#  'CarLongPlateGen2920.txt',
#  'cropngoaigiao4.jpg',
#  'CarLongPlateGen2595.txt',
#  'xemay1481.jpg',
#  'CarLongPlateGen1933.jpg',
#  'xemay2027.txt',
#  'CarLongPlate214.txt',
#  'CarLongPlateGen561.txt',
#  'CarLongPlateGen3337.txt',
#  'CarLongPlateGen484.jpg',
#  'xemayBigPlate109.txt',
#  'CarLongPlate130.jpg',
#  'CarLongPlateGen2516.txt',
#  'quandoi26.txt',
#  'xemay561.txt',
#  'CarLongPlateGen2037.jpg',
#  'xemay1155.txt',
#  'xemay2118.jpg',
#  'CarLongPlateGen623.txt',
#  'CarLongPlateGen3626.txt',
#  'CarLongPlateGen195.txt',
#  'xemay1920.txt',
#  'xemay1838.txt',
#  'CarLongPlateGen3068.jpg',
#  'xemay1167.txt',
#  'CarLongPlateGen2111.jpg',
#  'xemay2267.txt',
#  'CarLongPlateGen2087.jpg',
#  'CarLongPlateGen1019.txt',
#  'xemay738.jpg',
#  'CarLongPlate731.jpg',
#  'CarLongPlate428.jpg',
#  'xemayBigPlate124.jpg',
#  'rotatequandoi59.txt',
#  'CarLongPlateGen3336.txt',
#  'xemay710.txt',
#  'xemay2111.txt',
#  'boderquandoi11.txt',
#  'CarLongPlate129.txt',
#  'brightnessquandoi1.txt',
#  'xemay209.txt',
#  'xemayBigPlate209.txt',
#  'xemay1374.jpg',
#  'xemay350.jpg',
#  'CarLongPlateGen3392.txt',
#  'CarLongPlateGen3146.txt',
#  'CarLongPlateGen3262.jpg',
#  'CarLongPlateGen3272.jpg',
#  'CarLongPlateGen2300.jpg',
#  'CarLongPlateGen2937.txt',
#  'CarLongPlateGen2233.jpg',
#  'xemayBigPlate42.jpg',
#  'CarLongPlateGen3112.jpg',
#  'CarLongPlateGen1557.jpg',
#  'CarLongPlateGen668.txt',
#  'xemay373.jpg',
#  'CarLongPlate538.jpg',
#  'CarLongPlateGen1135.jpg',
#  'xemay1621.txt',
#  'xemay1198.txt',
#  'CarLongPlateGen3711.txt',
#  'xemay2279.jpg',
#  'CarLongPlateGen1056.jpg',
#  'ngoaigiao9.jpg',
#  'xemay1201.jpg',
#  'CarLongPlateGen3818.jpg',
#  'rotatequandoi40.jpg',
#  'xemayBigPlate203.jpg',
#  'CarLongPlateGen1321.jpg',
#  'xemay2371.txt',
#  'xemay239.txt',
#  'cropquandoi81.txt',
#  'CarLongPlateGen1994.jpg',
#  'rotatequandoi109.txt',
#  'CarLongPlateGen3118.jpg',
#  'cropquandoi91.txt',
#  'CarLongPlateGen757.txt',
#  'xemay1567.txt',
#  'CarLongPlateGen1960.jpg',
#  'xemay1891.jpg',
#  'CarLongPlateGen3297.txt',
#  'CarLongPlateGen2780.txt',
#  'xemay1940.txt',
#  'CarLongPlateGen3861.txt',
#  'quandoi37.txt',
#  'CarLongPlateGen2880.jpg',
#  'CarLongPlate683.txt',
#  'CarLongPlateGen1917.jpg',
#  'CarLongPlate796.jpg',
#  'CarLongPlate773.txt',
#  'CarLongPlate37.txt',
#  'CarLongPlateGen3097.jpg',
#  'CarLongPlateGen2345.jpg',
#  'CarLongPlateGen2491.jpg',
#  'CarLongPlateGen3013.jpg',
#  'xemayBigPlate166.txt',
#  'CarLongPlateGen2017.txt',
#  'xemay2249.txt',
#  'boderquandoi49.jpg',
#  'xemay234.jpg',
#  'CarLongPlate364.txt',
#  'CarLongPlate146.jpg',
#  'xemay879.txt',
#  'CarLongPlateGen317.txt',
#  'CarLongPlateGen3395.jpg',
#  'CarLongPlateGen3230.jpg',
#  'quandoi109.txt',
#  'xemay1525.jpg',
#  'CarLongPlateGen2936.jpg',
#  'CarLongPlateGen3855.txt',
#  'CarLongPlateGen3825.jpg',
#  'CarLongPlateGen3196.txt',
#  'CarLongPlateGen2954.jpg',
#  'CarLongPlate886.jpg',
#  'CarLongPlateGen2695.jpg',
#  'CarLongPlateGen3411.txt',
#  'CarLongPlate812.jpg',
#  'CarLongPlateGen1452.txt',
#  'xemay166.jpg',
#  'CarLongPlateGen2808.txt',
#  'xemay1134.txt',
#  'xemay2475.txt',
#  'CarLongPlateGen230.txt',
#  'CarLongPlateGen3299.jpg',
#  'CarLongPlateGen3508.jpg',
#  'xemay2070.jpg',
#  'CarLongPlateGen2951.txt',
#  'CarLongPlateGen2843.jpg',
#  'CarLongPlateGen1534.jpg',
#  'xemay2075.jpg',
#  'boderquandoi60.jpg',
#  'CarLongPlateGen3766.jpg',
#  'brightnessquandoi38.jpg',
#  'xemay1086.jpg',
#  'xemay144.jpg',
#  'brightnessquandoi28.txt',
#  'CarLongPlateGen342.txt',
#  'CarLongPlate316.txt',
#  'xemay391.jpg',
#  'CarLongPlateGen3483.jpg',
#  'xemay1181.jpg',
#  'xemay347.jpg',
#  'CarLongPlate439.txt',
#  'CarLongPlate359.jpg',
#  'CarLongPlateGen2356.jpg',
#  'CarLongPlateGen84.jpg',
#  'xemay1826.txt',
#  'brightnessquandoi96.txt',
#  'CarLongPlateGen2942.txt',
#  'CarLongPlate504.jpg',
#  'xemay480.txt',
#  'CarLongPlateGen3232.txt',
#  'xemay1418.txt',
#  'CarLongPlateGen373.jpg',
#  'xemay633.txt',
#  'CarLongPlate11.txt',
#  'CarLongPlateGen1454.jpg',
#  'CarLongPlateGen1694.txt',
#  'CarLongPlate83.jpg',
#  'CarLongPlateGen3241.jpg',
#  'CarLongPlateGen3712.txt',
#  'xemay2276.jpg',
#  'CarLongPlateGen2460.jpg',
#  'CarLongPlateGen654.jpg',
#  'CarLongPlateGen956.txt',
#  'xemay1387.jpg',
#  'CarLongPlate574.txt',
#  'CarLongPlateGen1749.jpg',
#  'CarLongPlateGen3409.txt',
#  'CarLongPlate755.txt',
#  'xemay244.jpg',
#  'xemay549.txt',
#  'xemay261.jpg',
#  'brightnessquandoi81.jpg',
#  'CarLongPlateGen227.txt',
#  'CarLongPlateGen3229.jpg',
#  'CarLongPlate566.jpg',
#  'CarLongPlateGen724.jpg',
#  'boderquandoi69.jpg',
#  'xemay2091.jpg',
#  'brightnessquandoi55.jpg',
#  'xemay41.jpg',
#  'CarLongPlate115.txt',
#  'CarLongPlate140.txt',
#  'CarLongPlateGen1147.jpg',
#  ...]

# %%
# we need to get all images and their corresponding labels into csv in order to visualized some samples.
# the data is already in yolo format, and we will need to change it also for fastercnn
# Yolo data looks as < obj-ID> <x_center> <y_center> <bbox_width> <bbox_height>

# %%
BASE_DIR = "/kaggle/input/yolo-plate-dataset/yolo_plate_dataset"

# %%
# lets check an example
open(f"{BASE_DIR}/CarLongPlate100.txt").read().split("\n ")
# Out:
# ['0 0.550847 0.599010 0.224576 0.089109\n']

# %%
def yolo_to_csv(data_path, output_csv):
    data = []
    # we iterate everything
    for idx, label_file in enumerate(os.listdir(data_path)):
        if label_file.endswith('.txt'):
            # get the corresponding image file
            image_file = label_file.replace('.txt', '.jpg')
            
            # full path to the label file and the image file
            label_path = os.path.join(data_path, label_file)
            image_path = os.path.join(data_path, image_file)
            
            # check if the image exists
            if os.path.exists(image_path):

                #read image to get the sizes, we will use h,w to un-normalize the labels
                with PILImage.open(image_path) as img:
                    image_width, image_height = img.size
                
                # read the labels
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    
                    # get the data for it through each object in the label file
                    for line in lines:
                        # split the line by space into components
                        parts = line.strip().split()
                        
                        if len(parts) == 5:
                            class_id, x_center, y_center, width, height = map(float, parts)

                            # Calculate unnormalized coordinates
                            x_center_unormalized = x_center * image_width
                            y_center_unormalized = y_center * image_height
                            width_unormalized = width * image_width
                            height_unormalized = height * image_height
                            
                            # Calculate bounding box corners
                            x_min = x_center_unormalized - (width_unormalized / 2)
                            y_min = y_center_unormalized - (height_unormalized / 2)
                            x_max = x_center_unormalized + (width_unormalized / 2)
                            y_max = y_center_unormalized + (height_unormalized / 2)

                            
                            data.append([image_file, int(class_id), x_center, y_center, width, height,x_min, y_min, x_max, y_max, image_width, image_height])
    
    # create a df
    df = pd.DataFrame(data, columns=['image_filename', 'class_id', 'x_center', 'y_center', 'bbox_width', 'bbox_height', 'x_min', 'y_min', 'x_max', 'y_max', 'image_width','image_height',])
    
    df.to_csv(output_csv, index=False)
    print(f"CSV saved to {output_csv}")

yolo_to_csv(f"{BASE_DIR}", "labels.csv")
# Out:
# CSV saved to labels.csv

# %%
 df = pd.read_csv("labels.csv")
df.head(8)
# Out:
#             image_filename  class_id  x_center  y_center  bbox_width  \
# 0  CarLongPlateGen2621.jpg         0  0.403602  0.534653    0.290254
# 1      CarLongPlate708.jpg         0  0.355932  0.841584    0.224576
# 2            xemay1617.jpg         0  0.455508  0.397690    0.182203
# 3          ngoaigiao10.jpg         0  0.336268  0.634831    0.109155
# 4  CarLongPlateGen3435.jpg         0  0.594280  0.549505    0.180085
# 5            xemay1884.jpg         0  0.385593  0.537954    0.105932
# 6      CarLongPlate873.jpg         0  0.453390  0.661716    0.228814
# 7  CarLongPlateGen1893.jpg         0  0.425847  0.405941    0.228814
#
#    bbox_height       x_min       y_min       x_max       y_max  image_width  \
# 0     0.125413  122.000200  142.999790  259.000088  180.999929          472
# 1     0.099010  114.999968  239.999937  220.999840  269.999967          472
# 2     0.240924  171.999868   84.000084  257.999684  157.000056          472
# 3     0.123596   80.000102  101.999874  111.000122  123.999962          284
# 4     0.194719  238.000100  137.000087  323.000220  195.999944          472
# 5     0.125413  156.999944  143.999993  206.999848  182.000132          472
# 6     0.089109  159.999976  186.999934  268.000184  213.999962          472
# 7     0.112211  146.999680  106.000157  254.999888  140.000090          472
#
#    image_height
# 0           303
# 1           303
# 2           303
# 3           178
# 4           303
# 5           303
# 6           303
# 7           303

# %%
df.class_id.unique()
# Out:
# array([0])

# %%
def plot_licence_plates_bbox(image_name):
    
    fig, ax = plt.subplots(1, 2, figsize = (14, 14))
    ax = ax.flatten()
    
    bbox = df[df['image_filename'] == image_name]
    img_path = f"{BASE_DIR}/{image_name}"
    
    image = cv2.imread(img_path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
    image /= 255.0
    image2 = image
    
    ax[0].set_title('Original Image')
    ax[0].imshow(image)
    
    for idx, row in bbox.iterrows():
        x1 = row['x_min']
        y1 = row['y_min']
        x2 = row['x_max']
        y2 = row['y_max']
        label = row['class_id']
        color_brg = (255,0,0)
        cv2.rectangle(image2, (int(x1),int(y1)), (int(x2),int(y2)), (255,0,0), 2)
    
    ax[1].set_title('Image with Boundary Box')
    ax[1].imshow(image2)

    plt.show()

# %%
plot_licence_plates_bbox("ngoaigiao10.jpg")

# %%
for each_filename in df.sample(5)["image_filename"].values:
    plot_licence_plates_bbox(each_filename)

# %%
unq_values = df["image_filename"].unique()
print("Total Records: ", len(df))
print("Unique Images: ",len(unq_values))

null_values = df.isnull().sum(axis = 0)
print("\n> Null Values in each column <")
print(null_values)
# Out:
# Total Records:  8452
# Unique Images:  8259
#
# > Null Values in each column <
# image_filename    0
# class_id          0
# x_center          0
# y_center          0
# bbox_width        0
# bbox_height       0
# x_min             0
# y_min             0
# x_max             0
# y_max             0
# image_width       0
# image_height      0
# dtype: int64

# %%
classes = df["class_id"].unique()
print("Total Classes: ",len(classes))
print("\n> Classes <\n",classes)
# Out:
# Total Classes:  1
#
# > Classes <
#  [0]

# %%
df.groupby("image_filename").count()
# Out:
#                      class_id  x_center  y_center  bbox_width  bbox_height  \
# image_filename
# CarLongPlate0.jpg           1         1         1           1            1
# CarLongPlate1.jpg           1         1         1           1            1
# CarLongPlate10.jpg          1         1         1           1            1
# CarLongPlate100.jpg         1         1         1           1            1
# CarLongPlate101.jpg         1         1         1           1            1
# ...                       ...       ...       ...         ...          ...
# xemayBigPlate95.jpg         1         1         1           1            1
# xemayBigPlate96.jpg         1         1         1           1            1
# xemayBigPlate97.jpg         1         1         1           1            1
# xemayBigPlate98.jpg         1         1         1           1            1
# xemayBigPlate99.jpg         1         1         1           1            1
#
#                      x_min  y_min  x_max  y_max  image_width  image_height
# image_filename
# CarLongPlate0.jpg        1      1      1      1            1             1
# CarLongPlate1.jpg        1      1      1      1            1             1
# CarLongPlate10.jpg       1      1      1      1            1             1
# CarLongPlate100.jpg      1      1      1      1            1             1
# CarLongPlate101.jpg      1      1      1      1            1             1
# ...                    ...    ...    ...    ...          ...           ...
# xemayBigPlate95.jpg      1      1      1      1            1             1
# xemayBigPlate96.jpg      1      1      1      1            1             1
# xemayBigPlate97.jpg      1      1      1      1            1             1
# xemayBigPlate98.jpg      1      1      1      1            1             1
# xemayBigPlate99.jpg      1      1      1      1            1             1
#
# [8259 rows x 11 columns]
